# %% [markdown]
# 6.1

# %%
import pandas as pd
import glob
import os
import numpy as np

# %%
files = os.path.join('/Users/[editted]/Documents/Boston_Crime', '*.csv' )
files = glob.glob(files)
df = pd.concat(map(pd.read_csv, files), ignore_index = True)
print(df)
# Out:
# /var/folders/r8/83_dlqf14nn0b3855_ng_wsh0000gn/T/ipykernel_72895/2273255238.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat(map(pd.read_csv, files), ignore_index = True)
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0            102091671          2647                 NaN
# 1            102095489          3115                 NaN
# 2            102096818          2905                 NaN
# 3            129092894          3201                 NaN
# 4            129099920          3301                 NaN
# ...                ...           ...                 ...
# 158073        20063425          3114                 NaN
# 158074        20062356          1107                 NaN
# 158075        20046400          1501                 NaN
# 158076        20038446          1501                 NaN
# 158077        20030892           540                 NaN
#
# ...

# %%
df.drop_duplicates()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0            102091671          2647                 NaN
# 1            102095489          3115                 NaN
# 2            102096818          2905                 NaN
# 3            129092894          3201                 NaN
# 4            129099920          3301                 NaN
# ...                ...           ...                 ...
# 158073        20063425          3114                 NaN
# 158074        20062356          1107                 NaN
# 158075        20046400          1501                 NaN
# 158076        20038446          1501                 NaN
# 158077        20030892           540                 NaN
#
#                                       OFFENSE_DESCRIPTION DISTRICT  \
# 0                               THREATS TO DO BODILY HARM       B3
# 1                                      INVESTIGATE PERSON      E18
# 2                             VAL - VIOLATION OF AUTO LAW       A1
# ...

# %%
print(df.dropna(axis = 1))
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE  \
# 0            102091671          2647
# 1            102095489          3115
# 2            102096818          2905
# 3            129092894          3201
# 4            129099920          3301
# ...                ...           ...
# 158073        20063425          3114
# 158074        20062356          1107
# 158075        20046400          1501
# 158076        20038446          1501
# 158077        20030892           540
#
#                                       OFFENSE_DESCRIPTION REPORTING_AREA  \
# 0                               THREATS TO DO BODILY HARM            417
# 1                                      INVESTIGATE PERSON            520
# 2                             VAL - VIOLATION OF AUTO LAW
# 3                                PROPERTY - LOST/ MISSING            503
# 4                                          VERBAL DISPUTE            330
# ...                                                   ...            ...
# ...

# %%
df.to_csv('cleaned.csv')

# %% [markdown]
# 6.2

# %%
cb_df = pd.read_csv('cleaned.csv')
print(cb_df)
# Out:
#         Unnamed: 0 INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0                0       102091671          2647                 NaN
# 1                1       102095489          3115                 NaN
# 2                2       102096818          2905                 NaN
# 3                3       129092894          3201                 NaN
# 4                4       129099920          3301                 NaN
# ...            ...             ...           ...                 ...
# 158073      158073        20063425          3114                 NaN
# 158074      158074        20062356          1107                 NaN
# 158075      158075        20046400          1501                 NaN
# 158076      158076        20038446          1501                 NaN
# 158077      158077        20030892           540                 NaN
#
#                                       OFFENSE_DESCRIPTION DISTRICT  \
# 0                               THREATS TO DO BODILY HARM       B3
# ...

# %%
YM_table = pd.crosstab(index = cb_df['MONTH'], columns = cb_df['YEAR'])
YM_table
# Out:
# YEAR   2019  2020
# MONTH
# 1      6958  6342
# 2      6173  5897
# 3      7093  5513
# 4      6963  4387
# 5      7783  5439
# 6      7635  5925
# 7      8083  6236
# 8      8430  6533
# 9      8184  6484
# 10     7121  6766
# 11     6468  5770
# 12     6293  5602

# %% [markdown]
# 6.3

# %%
pd.crosstab(index = cb_df['DISTRICT'], columns = cb_df['YEAR'])
# Out:
# YEAR       2019   2020
# DISTRICT
# A1         9936   7013
# A15        1889   1600
# A7         3400   3141
# B2        13030  10442
# B3         9591   7828
# C11       11022   8992
# C6         6286   5440
# D14        5704   4756
# D4        11276   9283
# E13        4928   4103
# E18        5197   4177
# E5         3807   3595
# External     77    246

# %% [markdown]
# The district B2 is obviously had more incident cases than other ditricts, and we can also see the incidents abated from 2019 to 2020, so we can say that the security was enhanced through the years. Meanwhile, A15 has the least cases during two years, but we cannot know the deep reason of it (acreage or security).
