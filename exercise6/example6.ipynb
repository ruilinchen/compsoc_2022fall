# %%
###set up work dir and read files

import os

os.chdir('/Users/[editted]/Documents/compsoc/code/boston_crime2019')

import pandas as pd

df_2019=pd.read_csv('boscrime2019.csv')
df_2020=pd.read_csv('boscrime2020.csv')
# Out:
# /Users/sophia/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### Task 6.1 Combine year 2019 and year 2020’s crime records into one pandas dataframe. Drop duplicates as well as any record that has missing values in the following columns: “INCIDENT_NUMBER”, “OFFENSE_CODE”, “DISTRICT”, “Long”, “Lat”, “SHOOTING”, “OCCURRED_ON_DATE”. Save the “cleaned” pandas dataframe to a separate csv file. ###

# %%
df= pd.concat([df_2019, df_2020], ignore_index=True, sort =False)
#combine
print(df)

df = df.dropna(subset=['INCIDENT_NUMBER', 'OFFENSE_CODE', 'DISTRICT', 'Long', 'Lat', 'SHOOTING', 'OCCURRED_ON_DATE'])
#drop missing
print(df)

df_clean=df.drop_duplicates()
#drop duplicates 
print(df_clean.duplicated().sum())

df_clean.to_csv('df_clean.csv')
#save new file
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0            102091671          2647                 NaN
# 1            102095489          3115                 NaN
# 2            102096818          2905                 NaN
# 3            129092894          3201                 NaN
# 4            129099920          3301                 NaN
# ...                ...           ...                 ...
# 158073        20063425          3114                 NaN
# 158074        20062356          1107                 NaN
# 158075        20046400          1501                 NaN
# 158076        20038446          1501                 NaN
# 158077        20030892           540                 NaN
#
#                                       OFFENSE_DESCRIPTION DISTRICT  \
# 0                               THREATS TO DO BODILY HARM       B3
# 1                                      INVESTIGATE PERSON      E18
# 2                             VAL - VIOLATION OF AUTO LAW       A1
# ...

# %% [markdown]
# ### Task 6.2 Read the csv file generated from Task 6.1 as a pandas dataframe. Use functions inside pandas to create a frequency table that counts the total number of crime incidents in Boston in each month from 2019 to 2020. Print this table. ###

# %%
df=pd.read_csv('df_clean.csv')
# read new file 

print(df[['YEAR', 'MONTH']].value_counts())
#unsorted 

count = df.groupby(['YEAR', 'MONTH']).size()
print(count)
#sorted frequency table
# Out:
# YEAR  MONTH
# 2019  8        8379
#       9        8133
#       7        8036
#       5        7763
#       6        7597
#       3        7065
#       10       6990
#       4        6936
#       1        6933
# 2020  10       6741
#       8        6507
#       9        6467
# 2019  11       6338
# 2020  1        6318
#       7        6213
# 2019  2        6147
# 2020  6        5897
#       2        5874
# 2019  12       5826
# 2020  11       5755
#       12       5581
#       3        5490
#       5        5411
#       4        4362
# dtype: int64
# YEAR  MONTH
# 2019  1        6933
#       2        6147
#       3        7065
#       4        6936
#       5        7763
#       6        7597
#       7        8036
#       8        8379
#       9        8133
#       10       6990
#       11       6338
#       12       5826
# 2020  1        6318
#       2        5874
#       3        5490
#       4        4362
#       5        5411
#       6        5897
#       7        6213
# ...

# %% [markdown]
# ### Task 6.3 Count the total number of crime incidents in each year by district (column “DISTRICT” in the data). Ignore DISTRACT with null value as well as value  “External”. Discuss the spatial distribution of crime. Do you see any significant difference between districts in terms of their crime counts?  ###

# %%
count_dis = df.groupby(['YEAR', 'DISTRICT']).size()
print(count_dis)

count_dis = df.groupby(['YEAR','DISTRICT']).size().reset_index(
  name='Count').sort_values(['Count'], ascending=False)
#sort according to frequency

count_dis
# Out:
# YEAR  DISTRICT
# 2019  A1           9936
#       A15          1889
#       A7           3400
#       B2          13030
#       B3           9591
#       C11         11022
#       C6           6286
#       D14          5704
#       D4          11276
#       E13          4928
#       E18          5197
#       E5           3807
#       External       77
# 2020  A1           7013
#       A15          1600
#       A7           3141
#       B2          10442
#       B3           7828
#       C11          8992
#       C6           5440
#       D14          4756
#       D4           9283
#       E13          4103
#       E18          4177
#       E5           3595
#       External      246
# dtype: int64
#     YEAR  DISTRICT  Count
# 3   2019        B2  13030
# 8   2019        D4  11276
# 5   2019       C11  11022
# 16  2020        B2  10442
# 0   2019        A1   9936
# 4   2019        B3   9591
# 21  2020        D4   9283
# 18  2020       C11   8992
# 17  2020        B3   7828
# ...

# %% [markdown]
#  - The differences in crime counts between districts are significant. We can see patterns of crime concentrations as crime counts are especially high in certain districts such as B2 and D4.
#  - E5, A7, and A15 are among the safest districts with least crime counts.
