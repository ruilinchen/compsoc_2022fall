# %% [markdown]
# # Test 1
# ## Task 1
# Integrate information from the “job_url_data” folder into one dictionary. The keys of the dictionary are individual urls scraped from the website, and the values are the earliest date that the corresponding urls were scraped. Save the results into a json file. How many unique job urls have been collected between May 17, 2022 and May 23, 2022?

# %%
import pandas
import os
os.chdir(r'C:/Users/SLdra/Documents/Me/BC/Advance/Data/jupyter/Test 1/job_url_data')

# %%
os.listdir() #need to reverse it
# Out:
# ['.DS_Store',
#  'job_urls_for_parsehub_5172022_v1.csv',
#  'job_urls_for_parsehub_5172022_v2.csv',
#  'job_urls_for_parsehub_5172022_v3.csv',
#  'job_urls_for_parsehub_5172022_v4.csv',
#  'job_urls_for_parsehub_5172022_v5.csv',
#  'job_urls_for_parsehub_5182022_v1.csv',
#  'job_urls_for_parsehub_5192022_v1.csv',
#  'job_urls_for_parsehub_5192022_v2.csv',
#  'job_urls_for_parsehub_5202022_v1.csv',
#  'job_urls_for_parsehub_5202022_v2.csv',
#  'job_urls_for_parsehub_5212022_v1.csv',
#  'job_urls_for_parsehub_5212022_v2.csv',
#  'job_urls_for_parsehub_5222022_v1.csv',
#  'job_urls_for_parsehub_5222022_v2.csv',
#  'job_urls_for_parsehub_5232022_v1.csv',
#  'job_urls_for_parsehub_5232022_v2.csv']

# %%
from datetime import datetime
jobdict = {}
for filename in reversed(os.listdir()):
    if filename[-3:] == "csv":
        filedate = filename.split("_")[-2]
        #who named these files without month/day padding?
        filedate = datetime.strptime("0"+filedate, '%m%d%Y').strftime("%Y-%m-%d") #only works for months<10 and days>9, bc bad naming convention
        data = pandas.read_csv(filename)
        for line in data['job_url']:
            jobdict[line] = filedate

# %%
import json
os.chdir(r'C:/Users/SLdra/Documents/Me/BC/Advance/Data/jupyter/Test 1')
with open("unique_urls.json", "w") as url_file:
    json.dump(jobdict, url_file)

# %%
print("There are", len(jobdict), "unique job urls between 2022-05-17 and 2022-05-23")
# Out:
# There are 21260 unique job urls between 2022-05-17 and 2022-05-23

# %% [markdown]
# ## Task 2
# Clean and integrate information from the “job_info_data” folder into one data frame. Files from this subfolder might have two different formats. Some of them are csv files, while others are json files. The columns might also be named differently. Find ways to read each of the files into pandas, drop records with missing job titles and/or missing job descriptions, and combine them into one dataframe. Lastly, drop records with duplicate job urls, and then save them into a separate csv file. How many unique jobs are there in the cleaned dataframe?

# %%
os.chdir(r'C:/Users/SLdra/Documents/Me/BC/Advance/Data/jupyter/Test 1/job_info_data')
job_info = pandas.DataFrame(columns=['Company', 'Job Title', 'Location', 'Description', 'Company Link', 'Job Link'])
jsonMap = {'link':'Job Link', 'job_title':'Job Title', 'company':'Company', 'company_url':'Company Link',
                      'company_location':'Location', 'job_description':'Description'}
csvMap = {}
missJobs = job_info.copy()
for key in jsonMap:
    csvMap["lnks_"+key] = jsonMap[key]
for filename in os.listdir():
    if filename[-3:] == "csv":
        data = pandas.read_csv(filename)
        if(len(data.dtypes) != len(csvMap)):
            print("Unusual data, investigate")
            break
        data.rename(columns=csvMap, inplace=True)
        data = data.query('`Job Title`.notna() & `Description`.notna()')
        job_info = pandas.concat([job_info, data])
    elif filename[-4:] == "json":
        with open(filename, encoding='UTF8') as jsonfile:
            otherdata = json.load(jsonfile)
            data = pandas.DataFrame.from_dict(otherdata['lnks'])
            if(len(data.dtypes) != len(jsonMap)):
                print("Unusual data, investigate")
                break
            data.rename(columns=jsonMap, inplace=True)
            data = data.query('`Job Title`.notna() & `Description`.notna()')
            job_info = pandas.concat([job_info, data])

# %%
job_info.head()
# Out:
#                         Company  \
# 0                          USAA
# 1  Pikes Peak Community College
# 2      Memorial Regional Health
# 3                        Jacobs
# 4           Swiss American CDMO
#
#                                         Job Title                    Location  \
# 0       Senior Audit Manager- Compliance (Remote)      Happy Valley Ranch, AZ
# 1                               Access Specialist  Colorado Springs, CO 80906
# 2  Clinic Registered Nurse - Family Practice - FT             Craig, CO 81625
# 3      Sr Wetland Scientist/Permitting Specialist      Wethersfield, CT 06109
# 4                      Quality Assurance Engineer        Carrollton, TX 75006
#
#                                          Description  \
# 0  Purpose of Job We are seeking a talented Senio...
# 1  Tracking Code: 40069\nWork Type: Full-time\nCa...
# 2  Position Purpose: The Registered Nurse is resp...
# 3  Our People & Places Solutions business – reinf...
# 4  QUALITY ASSURANCE ENGINEER II\nPosition Summar...
#
#                                         Company Link  \
# 0  https://www.indeed.com/cmp/Usaa?campaignid=mob...
# 1  https://www.indeed.com/cmp/Pikes-Peak-Communit...
# 2  https://www.indeed.com/cmp/Memorial-Regional-H...
# 3  https://www.indeed.com/cmp/Jacobs?campaignid=m...
# 4  https://www.indeed.com/cmp/Swiss-American-Cdmo...
#
#                                             Job Link
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/rc/clk?jk=bf3aa4d4d8608...
# 2  https://www.indeed.com/rc/clk?jk=ceee36181304b...
# 3  https://www.indeed.com/rc/clk?jk=e9735aea38be9...
# 4  https://www.indeed.com/company/Swiss-American-...

# %%
print("Before job link filter", len(job_info))
job_info.drop_duplicates('Job Link', inplace=True)
print("After job link filter", len(job_info))
job_info.drop_duplicates(['Company', 'Job Title', 'Location', 'Description'], inplace=True) #about 2000 of these
# Out:
# Before job link filter 21510
# After job link filter 16303

# %%
print("With all filters there are", len(job_info), "unique jobs")
# Out:
# With all filters there are 14387 unique jobs

# %% [markdown]
# ## Task 3
# Merge between “job_url_data” and “job_info_data”. What is the percentage of jobs that can be matched between these two data sources? How are the missing data (unmatched job urls) distributed by date? What about matched job urls? How many complete job listings were we able to collect each day? How would you interpret this result with respect to data quality? Does it mean that our data collection strategy is flawed and thus introduces non-random sampling biases?

# %%
os.chdir(r'C:/Users/SLdra/Documents/Me/BC/Advance/Data/jupyter/Test 1')
with open("unique_urls.json") as url_file:
    otherdata = json.load(url_file)

# %%
url_data = pandas.DataFrame(otherdata.items(), columns=['Job Link', 'Date'])

# %%
url_data.head()
# Out:
#                                             Job Link        Date
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-21
# 1  https://www.indeed.com/rc/clk?jk=0ae589447d347...  2022-05-22
# 2  https://www.indeed.com/rc/clk?jk=77efd97a2f20a...  2022-05-22
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-23
# 4  https://www.indeed.com/company/Golding-Farms-F...  2022-05-23

# %%
print(len(url_data))
print(len(job_info))
# Out:
# 21260
# 14387

# %%
job_with_date = pandas.merge(job_info, url_data, how='inner', on='Job Link')

# %%
job_with_date.head()
# Out:
#                         Company  \
# 0                          USAA
# 1  Pikes Peak Community College
# 2      Memorial Regional Health
# 3                        Jacobs
# 4           Swiss American CDMO
#
#                                         Job Title                    Location  \
# 0       Senior Audit Manager- Compliance (Remote)      Happy Valley Ranch, AZ
# 1                               Access Specialist  Colorado Springs, CO 80906
# 2  Clinic Registered Nurse - Family Practice - FT             Craig, CO 81625
# 3      Sr Wetland Scientist/Permitting Specialist      Wethersfield, CT 06109
# 4                      Quality Assurance Engineer        Carrollton, TX 75006
#
#                                          Description  \
# 0  Purpose of Job We are seeking a talented Senio...
# 1  Tracking Code: 40069\nWork Type: Full-time\nCa...
# 2  Position Purpose: The Registered Nurse is resp...
# 3  Our People & Places Solutions business – reinf...
# 4  QUALITY ASSURANCE ENGINEER II\nPosition Summar...
#
#                                         Company Link  \
# 0  https://www.indeed.com/cmp/Usaa?campaignid=mob...
# 1  https://www.indeed.com/cmp/Pikes-Peak-Communit...
# 2  https://www.indeed.com/cmp/Memorial-Regional-H...
# 3  https://www.indeed.com/cmp/Jacobs?campaignid=m...
# 4  https://www.indeed.com/cmp/Swiss-American-Cdmo...
#
#                                             Job Link        Date
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17
# 1  https://www.indeed.com/rc/clk?jk=bf3aa4d4d8608...  2022-05-17
# 2  https://www.indeed.com/rc/clk?jk=ceee36181304b...  2022-05-17
# 3  https://www.indeed.com/rc/clk?jk=e9735aea38be9...  2022-05-17
# 4  https://www.indeed.com/company/Swiss-American-...  2022-05-17

# %%
print(round(100*len(job_with_date)/len(url_data), 3), "% of urls were matched with jobs")
# Out:
# 67.672 % of urls were matched with jobs

# %%
link_missing_info = pandas.concat([job_with_date[['Job Link', 'Date']], url_data[['Job Link', 'Date']]]).drop_duplicates('Job Link', keep=False)

# %%
link_missing_info.head()
# Out:
#                                             Job Link        Date
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-21
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-23
# 4  https://www.indeed.com/company/Golding-Farms-F...  2022-05-23
# 5  https://www.indeed.com/rc/clk?jk=300796a784429...  2022-05-23
# 6  https://www.indeed.com/rc/clk?jk=0b291e71806f9...  2022-05-23

# %%
link_missing_info['Date'].value_counts()
# Out:
# 2022-05-23    3423
# 2022-05-17    1728
# 2022-05-21     681
# 2022-05-20     412
# 2022-05-19     326
# 2022-05-22     217
# 2022-05-18      86
# Name: Date, dtype: int64

# %%
link_missing_info['Date'].value_counts().sort_index() #I like this better
# Out:
# 2022-05-17    1728
# 2022-05-18      86
# 2022-05-19     326
# 2022-05-20     412
# 2022-05-21     681
# 2022-05-22     217
# 2022-05-23    3423
# Name: Date, dtype: int64

# %%
url_data['Date'].value_counts().sort_index()
# Out:
# 2022-05-17    5257
# 2022-05-18    1325
# 2022-05-19    3798
# 2022-05-20    4523
# 2022-05-21    2154
# 2022-05-22     780
# 2022-05-23    3423
# Name: Date, dtype: int64

# %%
#want to compare it to the frequency of those dates overall
link_missing_info['Date'].value_counts().sort_index().divide(url_data['Date'].value_counts().sort_index())
# Out:
# 2022-05-17    0.328705
# 2022-05-18    0.064906
# 2022-05-19    0.085835
# 2022-05-20    0.091090
# 2022-05-21    0.316156
# 2022-05-22    0.278205
# 2022-05-23    1.000000
# Name: Date, dtype: float64

# %%
#everything is one of those categories
accepted = ['pagead', 'rc', 'company']
frames = [link_missing_info, job_with_date]
for frame in frames:
    print(frame['Job Link'].str.split('/').str[3].value_counts())
# Out:
# pagead     3285
# rc         3094
# company     494
# Name: Job Link, dtype: int64
# rc         10502
# pagead      2308
# company     1577
# Name: Job Link, dtype: int64

# %%
#honestly not really a trend

# %% [markdown]
# The missing data is not randomly distributed between the days. For whatever reason there were more missing data on the first day of data collection, there is some chance this is due to some property of those jobs that were there since the first day of data collection (perhaps older ones or some error in the scraper, hard to tell from the data so thats just speculation). Also on the last day (2022-05-23) all of the data is missing, which likely indicates some sort of scraper error.
#
# Overall I would trust this data for broad conclusions about compliance jobs, but wouldn't trust it for specific numerical claims (or would put large confidence intervals on those claims). I would also revise the initial claim that data was collected from the 17th to the 23rd, making the interval the 17th to the 22nd instead, as no real data was collected on the 23rd.

# %% [markdown]
# ## Bonus Task 1
# Using the merged dataset from Task 3, extract state information for each individual job based on the “company_location” column. Aggregate them by state, and create a state-level choropleth map to visualize the spatial distribution of compliance jobs. The map should be colored based on the total number of compliance jobs in each state. The boundaries of US states in geojson can be found here. Interpret the results.

# %%
import geopandas as gpd
os.chdir(r'C:/Users/SLdra/Documents/Me/BC/Advance/Data/jupyter/Test 1/states')
state_boundaries = gpd.read_file('states.geojson')

# %%
job_with_date.head()
# Out:
#                         Company  \
# 0                          USAA
# 1  Pikes Peak Community College
# 2      Memorial Regional Health
# 3                        Jacobs
# 4           Swiss American CDMO
#
#                                         Job Title                    Location  \
# 0       Senior Audit Manager- Compliance (Remote)      Happy Valley Ranch, AZ
# 1                               Access Specialist  Colorado Springs, CO 80906
# 2  Clinic Registered Nurse - Family Practice - FT             Craig, CO 81625
# 3      Sr Wetland Scientist/Permitting Specialist      Wethersfield, CT 06109
# 4                      Quality Assurance Engineer        Carrollton, TX 75006
#
#                                          Description  \
# 0  Purpose of Job We are seeking a talented Senio...
# 1  Tracking Code: 40069\nWork Type: Full-time\nCa...
# 2  Position Purpose: The Registered Nurse is resp...
# 3  Our People & Places Solutions business – reinf...
# 4  QUALITY ASSURANCE ENGINEER II\nPosition Summar...
#
#                                         Company Link  \
# 0  https://www.indeed.com/cmp/Usaa?campaignid=mob...
# 1  https://www.indeed.com/cmp/Pikes-Peak-Communit...
# 2  https://www.indeed.com/cmp/Memorial-Regional-H...
# 3  https://www.indeed.com/cmp/Jacobs?campaignid=m...
# 4  https://www.indeed.com/cmp/Swiss-American-Cdmo...
#
#                                             Job Link        Date
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17
# 1  https://www.indeed.com/rc/clk?jk=bf3aa4d4d8608...  2022-05-17
# 2  https://www.indeed.com/rc/clk?jk=ceee36181304b...  2022-05-17
# 3  https://www.indeed.com/rc/clk?jk=e9735aea38be9...  2022-05-17
# 4  https://www.indeed.com/company/Swiss-American-...  2022-05-17

# %%
job_with_date.loc[job_with_date['Location'].str.split(' ').str[-2].isin(state_boundaries['STUSPS']), 'STUSPS'] = job_with_date['Location'].str.split(' ').str[-2]

# %%
job_with_date.loc[job_with_date['Location'].str.split(' ').str[-1].isin(state_boundaries['STUSPS']), 'STUSPS'] = job_with_date['Location'].str.split(' ').str[-1]

# %%
fullstate = job_with_date.loc[job_with_date['Location'].isin(state_boundaries['NAME']), 'Location']

# %%
fullstate = fullstate.to_frame().rename({'Location':'NAME'}, axis=1)

# %%
fullstate = fullstate.merge(state_boundaries[['NAME', 'STUSPS']], on='NAME')

# %%
fullstate.head()
# Out:
#          NAME STUSPS
# 0  New Jersey     NJ
# 1  New Jersey     NJ
# 2  New Jersey     NJ
# 3  New Jersey     NJ
# 4  New Jersey     NJ

# %%
#list because otherwise indices mess it up
job_with_date.loc[job_with_date['Location'].isin(state_boundaries['NAME']), 'STUSPS'] = list(fullstate['STUSPS'])

# %%
job_with_date.head()
# Out:
#                         Company  \
# 0                          USAA
# 1  Pikes Peak Community College
# 2      Memorial Regional Health
# 3                        Jacobs
# 4           Swiss American CDMO
#
#                                         Job Title                    Location  \
# 0       Senior Audit Manager- Compliance (Remote)      Happy Valley Ranch, AZ
# 1                               Access Specialist  Colorado Springs, CO 80906
# 2  Clinic Registered Nurse - Family Practice - FT             Craig, CO 81625
# 3      Sr Wetland Scientist/Permitting Specialist      Wethersfield, CT 06109
# 4                      Quality Assurance Engineer        Carrollton, TX 75006
#
#                                          Description  \
# 0  Purpose of Job We are seeking a talented Senio...
# 1  Tracking Code: 40069\nWork Type: Full-time\nCa...
# 2  Position Purpose: The Registered Nurse is resp...
# 3  Our People & Places Solutions business – reinf...
# 4  QUALITY ASSURANCE ENGINEER II\nPosition Summar...
#
#                                         Company Link  \
# 0  https://www.indeed.com/cmp/Usaa?campaignid=mob...
# 1  https://www.indeed.com/cmp/Pikes-Peak-Communit...
# 2  https://www.indeed.com/cmp/Memorial-Regional-H...
# 3  https://www.indeed.com/cmp/Jacobs?campaignid=m...
# 4  https://www.indeed.com/cmp/Swiss-American-Cdmo...
#
#                                             Job Link        Date STUSPS
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17     AZ
# 1  https://www.indeed.com/rc/clk?jk=bf3aa4d4d8608...  2022-05-17     CO
# 2  https://www.indeed.com/rc/clk?jk=ceee36181304b...  2022-05-17     CO
# 3  https://www.indeed.com/rc/clk?jk=e9735aea38be9...  2022-05-17     CT
# 4  https://www.indeed.com/company/Swiss-American-...  2022-05-17     TX

# %%
job_with_date.query('STUSPS.isna()')
# Out:
#                         Company  \
# 7             Pirouette Medical
# 14     Allay Therapeutics, Inc.
# 23               Total Wrecking
# 24                          NaN
# 42                          NaN
# ...                         ...
# 13432               PharmAllies
# 13599     Alaskan Dream Cruises
# 13786                     Amgen
# 14064    Fresenius Medical Care
# 14161                       NaN
#
#                                                Job Title  \
# 7      Vice President Quality Assurance and Regulator...
# 14                       Director of Clinical Operations
# 23                                       Safety Director
# 24                              Principal Medical Writer
# 42                  Clinical Trial Management (CTMs/COM)
# ...                                                  ...
# 13432           Validation Senior Manager - (Bio/Pharma)
# 13599                                    Captain 100 Ton
# 13786  Specialist Quality Assurance – AML 14 (Quality...
# 14064                                   Clinical Manager
# 14161                  Clinical Trial Manager - Oncology
#
#                       Location  \
# 7                United States
# 14               United States
# 23               United States
# 24               United States
# 42               United States
# ...                        ...
# 13432          Barceloneta, PR
# 13599            United States
# 13786  Municipio de Juncos, PR
# 14064       San Juan, PR 00926
# 14161             Carolina, PR
#
#                                              Description  \
# 7      Vice President, Quality Assurance (QA) and Reg...
# 14     Allay Therapeutics (www.allaytx.com) is pionee...
# 23     Total Wrecking is seeking an experienced Safet...
# 24     Description\nPrincipal Medical Writer\nCome di...
# 42     Description\nJOB SUMMARY\nThe Clinical Trial M...
# ...                                                  ...
# 13432  RELOCATION ASSISTANCE TO MADISON, WISCONSIN ME...
# 13599  COME EXPLORE WITH THE LOCALS! GREAT JOBS AVAIL...
# 13786  HOW MIGHT YOU DEFY IMAGINATION?\nYou’ve earned...
# 14064  PURPOSE AND SCOPE:\nSupports FMCNA’s mission, ...
# 14161  SUMMARY: Responsible for leading the delivery ...
#
#                                             Company Link  \
# 7      https://www.indeed.com/cmp/Pirouette-Medical?c...
# 14     https://www.indeed.com/cmp/Allay-Therapeutics,...
# 23     https://www.indeed.com/cmp/Asbestos-Demolition...
# 24                                                   NaN
# 42                                                   NaN
# ...                                                  ...
# 13432  https://www.indeed.com/cmp/Pharmallies?campaig...
# 13599  https://www.indeed.com/cmp/Alaskan-Dream-Cruis...
# 13786  https://www.indeed.com/cmp/Amgen?campaignid=mo...
# 14064  https://www.indeed.com/cmp/Fresenius-Medical-C...
# 14161                                                NaN
#
#                                                 Job Link        Date STUSPS
# 7      https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17    NaN
# 14     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17    NaN
# 23     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17    NaN
# 24     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17    NaN
# 42     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-17    NaN
# ...                                                  ...         ...    ...
# 13432  https://www.indeed.com/company/PharmAllies/job...  2022-05-20    NaN
# 13599  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-22    NaN
# 13786  https://www.indeed.com/rc/clk?jk=2d9d672fda30d...  2022-05-21    NaN
# 14064  https://www.indeed.com/rc/clk?jk=97e20bf5cda26...  2022-05-22    NaN
# 14161  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  2022-05-21    NaN
#
# [145 rows x 8 columns]

# %%
#just will drop the rest
job_with_date = job_with_date.query('STUSPS.notna()')

# %%
geojob = job_with_date.groupby('STUSPS').agg("Job Link").count().reset_index()

# %%
geojob.rename({'Job Link':'Job Count'}, axis=1, inplace=True)

# %%
geojob = state_boundaries[['STUSPS','geometry']].merge(geojob, on='STUSPS', how='inner')

# %%
geojob.head()
# Out:
#   STUSPS                                           geometry  Job Count
# 0     NE  MULTIPOLYGON (((-104.05303 43.00059, -103.6183...        114
# 1     WA  MULTIPOLYGON (((-122.52603 47.35891, -122.5139...        297
# 2     NM  MULTIPOLYGON (((-109.04522 36.99908, -108.6460...        130
# 3     SD  MULTIPOLYGON (((-104.05770 44.99743, -104.0397...         57
# 4     KY  MULTIPOLYGON (((-89.13268 36.98220, -89.16645 ...        174

# %%
import folium
clat = 40.0
clon = -95.0
m = folium.Map(location=(clat, clon), zoom_start=4, width=800, height=400, tiles="Cartodb Positron")

folium.Choropleth(
    geo_data=geojob,
    name="choropleth",
    data=geojob,
    columns= ["STUSPS", "Job Count"],
    key_on="feature.properties.STUSPS",
    fill_color="YlOrRd",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Compliance job count by zip code, May 2022").add_to(m)

folium.LayerControl().add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5aff47babff19355e794ab9ab6c3b298 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5aff47babff19355e794ab9ab6c3b298&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5aff47babff19355e794ab9ab6c3b298 = L.map(
#                 &quot;map_5aff47babff19355e794ab9ab6c3b298&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdea0b86f948866b6c3ee55bdf77f41f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5aff47babff19355e794ab9ab6c3b298);
#
#
#             var choropleth_c2dfe2030409114fd3b1830922974ab1 = L.featureGroup(
#                 {}
#             ).addTo(map_5aff47babff19355e794ab9ab6c3b298);
#
#
#         function geo_json_12966119f7bdee76a47ec04342133b2a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;9&quot;: case &quot;11&quot;: case &quot;13&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;40&quot;: case &quot;44&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;16&quot;: case &quot;27&quot;: case &quot;33&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;35&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;39&quot;: case &quot;48&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_12966119f7bdee76a47ec04342133b2a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_12966119f7bdee76a47ec04342133b2a = L.geoJson(null, {
#                 onEachFeature: geo_json_12966119f7bdee76a47ec04342133b2a_onEachFeature,
#
#                 style: geo_json_12966119f7bdee76a47ec04342133b2a_styler,
#         });
#
#         function geo_json_12966119f7bdee76a47ec04342133b2a_add (data) {
#             geo_json_12966119f7bdee76a47ec04342133b2a
#                 .addData(data)
#                 .addTo(choropleth_c2dfe2030409114fd3b1830922974ab1);
#         }
#             geo_json_12966119f7bdee76a47ec04342133b2a_add({&quot;bbox&quot;: [-170.0, 18.922445330354858, -66.97626, 71.352561], &quot;features&quot;: [{&quot;bbox&quot;: [-104.053249, 39.999998, -95.30829, 43.000784], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-104.053028, 43.000587], [-103.618334, 43.000679], [-103.132955, 43.000784], [-102.487329, 42.999559], [-101.849982, 42.999329], [-101.625424, 42.996238], [-101.000429, 42.99753], [-100.631728, 42.998092], [-99.918401, 42.998057], [-99.471353, 42.997967], [-98.899944, 42.998122], [-98.49855, 42.99856], [-98.467356, 42.947556], [-98.342408, 42.900847], [-98.325864, 42.8865], [-98.258276, 42.87439], [-98.219826, 42.853157], [-98.129038, 42.821228], [-98.035034, 42.764205], [-97.950147, 42.769619], [-97.888562, 42.817251], [-97.875345, 42.858724], [-97.84527, 42.867734], [-97.774456, 42.849774], [-97.686506, 42.842435], [-97.603762, 42.858329], [-97.561928, 42.847552], [-97.504847, 42.858477], [-97.442279, 42.846224], [-97.417066, 42.865918], [-97.359569, 42.854816], [-97.306677, 42.867604], [-97.289859, 42.855499], [-97.218825, 42.845848], [-97.210126, 42.809296], [-97.150763, 42.795566], [-97.131331, 42.771929], [-97.071849, 42.772305], [-96.982197, 42.760554], [-96.948902, 42.719465], [-96.906797, 42.7338], [-96.806223, 42.704154], [-96.802178, 42.672237], [-96.728024, 42.666882], [-96.687669, 42.653126], [-96.710995, 42.608128], [-96.685746, 42.577944], [-96.638033, 42.55196], [-96.625958, 42.513576

# %% [markdown]
# There are a high amount of compliance jobs in Texas and California, which is expected of those largest states.

# %%
#decided to normalize it by population
#data taken from the 2020 census
os.chdir(r'C:/Users/SLdra/Documents/Me/BC/Advance/Data/jupyter/Test 1')
pop = pandas.read_excel("NST-EST2021-POP.xlsx", header=None, names=["NAME", "Pop", "Ignore1", "Ignore2"],
                        skiprows=9)

# %%
pop.head()
# Out:
#           NAME         Pop     Ignore1     Ignore2
# 0     .Alabama   5024279.0   5024803.0   5039877.0
# 1      .Alaska    733391.0    732441.0    732673.0
# 2     .Arizona   7151502.0   7177986.0   7276316.0
# 3    .Arkansas   3011524.0   3012232.0   3025891.0
# 4  .California  39538223.0  39499738.0  39237836.0

# %%
pop['NAME'] = pop['NAME'].str.slice(1)

# %%
pop.head()
# Out:
#          NAME         Pop     Ignore1     Ignore2
# 0     Alabama   5024279.0   5024803.0   5039877.0
# 1      Alaska    733391.0    732441.0    732673.0
# 2     Arizona   7151502.0   7177986.0   7276316.0
# 3    Arkansas   3011524.0   3012232.0   3025891.0
# 4  California  39538223.0  39499738.0  39237836.0

# %%
pop = pop.merge(state_boundaries[['NAME', 'STUSPS']], on='NAME')

# %%
pop.head()
# Out:
#          NAME         Pop     Ignore1     Ignore2 STUSPS
# 0     Alabama   5024279.0   5024803.0   5039877.0     AL
# 1      Alaska    733391.0    732441.0    732673.0     AK
# 2     Arizona   7151502.0   7177986.0   7276316.0     AZ
# 3    Arkansas   3011524.0   3012232.0   3025891.0     AR
# 4  California  39538223.0  39499738.0  39237836.0     CA

# %%
geojob = geojob.merge(pop[['STUSPS', 'Pop']], on='STUSPS')

# %%
geojob.head()
# Out:
#   STUSPS                                           geometry  Job Count  \
# 0     NE  MULTIPOLYGON (((-104.05303 43.00059, -103.6183...        114
# 1     WA  MULTIPOLYGON (((-122.52603 47.35891, -122.5139...        297
# 2     NM  MULTIPOLYGON (((-109.04522 36.99908, -108.6460...        130
# 3     SD  MULTIPOLYGON (((-104.05770 44.99743, -104.0397...         57
# 4     KY  MULTIPOLYGON (((-89.13268 36.98220, -89.16645 ...        174
#
#          Pop
# 0  1961504.0
# 1  7705281.0
# 2  2117522.0
# 3   886667.0
# 4  4505836.0

# %%
geojob['Jobs per 1000'] = 1000*geojob['Job Count'].divide(geojob['Pop'])

# %%
geojob.head()
# Out:
#   STUSPS                                           geometry  Job Count  \
# 0     NE  MULTIPOLYGON (((-104.05303 43.00059, -103.6183...        114
# 1     WA  MULTIPOLYGON (((-122.52603 47.35891, -122.5139...        297
# 2     NM  MULTIPOLYGON (((-109.04522 36.99908, -108.6460...        130
# 3     SD  MULTIPOLYGON (((-104.05770 44.99743, -104.0397...         57
# 4     KY  MULTIPOLYGON (((-89.13268 36.98220, -89.16645 ...        174
#
#          Pop  Jobs per 1000
# 0  1961504.0       0.058119
# 1  7705281.0       0.038545
# 2  2117522.0       0.061393
# 3   886667.0       0.064286
# 4  4505836.0       0.038617

# %%
import folium
clat = 40.0
clon = -95.0
m = folium.Map(location=(clat, clon), zoom_start=4, width=800, height=400, tiles="Cartodb Positron")

folium.Choropleth(
    geo_data=geojob,
    name="choropleth",
    data=geojob,
    columns= ["STUSPS", "Jobs per 1000"],
    key_on="feature.properties.STUSPS",
    fill_color="YlOrRd",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Compliance job count by zip code, May 2022").add_to(m)

folium.LayerControl().add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca229638a14c2e216a771b9e1786b1c1 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca229638a14c2e216a771b9e1786b1c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ca229638a14c2e216a771b9e1786b1c1 = L.map(
#                 &quot;map_ca229638a14c2e216a771b9e1786b1c1&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1277272c3467b0b86ab2a91d01878f5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ca229638a14c2e216a771b9e1786b1c1);
#
#
#             var choropleth_05a02c502154762125e90838bd05348c = L.featureGroup(
#                 {}
#             ).addTo(map_ca229638a14c2e216a771b9e1786b1c1);
#
#
#         function geo_json_dbcdd534f531fe96fae3d8cadd33796b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;9&quot;: case &quot;14&quot;: case &quot;25&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;40&quot;: case &quot;43&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;38&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;50&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_dbcdd534f531fe96fae3d8cadd33796b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_dbcdd534f531fe96fae3d8cadd33796b = L.geoJson(null, {
#                 onEachFeature: geo_json_dbcdd534f531fe96fae3d8cadd33796b_onEachFeature,
#
#                 style: geo_json_dbcdd534f531fe96fae3d8cadd33796b_styler,
#         });
#
#         function geo_json_dbcdd534f531fe96fae3d8cadd33796b_add (data) {
#             geo_json_dbcdd534f531fe96fae3d8cadd33796b
#                 .addData(data)
#                 .addTo(choropleth_05a02c502154762125e90838bd05348c);
#         }
#             geo_json_dbcdd534f531fe96fae3d8cadd33796b_add({&quot;bbox&quot;: [-170.0, 18.922445330354858, -66.97626, 71.352561], &quot;features&quot;: [{&quot;bbox&quot;: [-104.053249, 39.999998, -95.30829, 43.000784], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-104.053028, 43.000587], [-103.618334, 43.000679], [-103.132955, 43.000784], [-102.487329, 42.999559], [-101.849982, 42.999329], [-101.625424, 42.996238], [-101.000429, 42.99753], [-100.631728, 42.998092], [-99.918401, 42.998057], [-99.471353, 42.997967], [-98.899944, 42.998122], [-98.49855, 42.99856], [-98.467356, 42.947556], [-98.342408, 42.900847], [-98.325864, 42.8865], [-98.258276, 42.87439], [-98.219826, 42.853157], [-98.129038, 42.821228], [-98.035034, 42.764205], [-97.950147, 42.769619], [-97.888562, 42.817251], [-97.875345, 42.858724], [-97.84527, 42.867734], [-97.774456, 42.849774], [-97.686506, 42.842435], [-97.603762, 42.858329], [-97.561928, 42.847552], [-97.504847, 42.858477], [-97.442279, 42.846224], [-97.417066, 42.865918], [-97.359569, 42.854816], [-97.306677, 42.867604], [-97.289859, 42.855499], [-97.218825, 42.845848], [-97.210126, 42.809296], [-97.150763, 42.795566], [-97.131331, 42.771929], [-97.071849, 42.772305], [-96.982197, 42.760554], [-96.948902, 42.719465], [-96.906797, 42.7338], [-96.806223, 42.704154], [-96.802178, 42.672237], [-96.728024, 42.666882], [-96.687669, 42.653126], [-96.710995, 42.608128], [-96.685746, 42.577944], [-96.638033, 42.55196], [-96.625958, 42.513576], [-96.603468, 42.50446], [-96.557775, 42.52038], [-96.525142, 42.510234], [-96.501321, 42.482749], [-96.445508, 42.49063], [-96.396107, 42.484095], [-96.380707, 42.446394], [-96.411808, 42.410894], [-96.407998, 42.337408], [-96.369969, 42.310878], [-96.368454, 42.291848], [-96.331331, 42.25943], [-96.323723, 42.229887], [-96.356591, 42.215182], [-96.347752, 42.166806], [-96.310085, 42.132523], [-96.267318, 42.110265], [-96.279079, 42.074026], [-96.27142

# %% [markdown]
# And now that its normalized, we can see that the central states have more compliance jobs per capita than most states.
